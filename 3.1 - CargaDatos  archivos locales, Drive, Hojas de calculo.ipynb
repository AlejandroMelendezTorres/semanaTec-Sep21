# %% [markdown]
# # Lectura de archivos
#
#
# Semana Tec
#
# Profesores: Luz Eunice Angeles /José Ignacio Treviño

# %% [markdown]
# Qué aprenderemos:
#
# - Subir archivos desde el sistema de archivos local
# - Descargar archivos en el slistema de archivos local
# - Acceder a google drive
#   - Activarlo de en el entorno de ejecución
#   - Usar una API : PyDrive
# - Crear y leer datos de google sheets

# %% [markdown]
# ## Subir archivos desde el sistema de archivos local
#
# <code>files.upload</code> es usado para cargar los archivos y conocer el diccionario de los archivos que se cargaron.
# El diccionario está codificado según el nombre de archivo y los valores son los datos que se subieron.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-9de08424-2e17-4158-a8e6-f08192e05c59" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9de08424-2e17-4158-a8e6-f08192e05c59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tmdb_5000_movies.csv to tmdb_5000_movies.csv
# User uploaded file "tmdb_5000_movies.csv" with length 5698602 bytes

# %% [markdown]
# ## Descargar archivos en el sistema de archivos local
#
# <code>files.download</code> invocará una descarga del archivo desde el navegador a tu computadora local.

# %%
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('some content')

files.download('example.txt')

# %%
ls
# Out:
# qna-metadata.csv  qna-relacion.csv   sample_data/
# qna-pregunta.csv  qna-respuesta.csv

# %% [markdown]
# # Google Drive
#
# Puedes acceder a archivos en Drive de varias maneras, incluidas las siguientes:
# - Activación de Google Drive en la máquina virtual del entorno de ejecución
# - Usar un wrapper alrededor de la API, como <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">PyDrive</a>
# - Usar la <a href="https://developers.google.com/drive/v3/web/about-sdk">API nativa de REST</a>
#
#
#
# Puedes ver ejemplos de cada caso más abajo.

# %% [markdown]
# ## Activar Google Drive de forma local
#
# El ejemplo siguiente muestra cómo activar Google Drive en el entorno de ejecución mediante un código de autorización y cómo escribir y leer archivos allí. Una vez ejecutado, podrás ver el archivo nuevo &#40;<code>foo.txt</code>&#41; en <a href="https://drive.google.com/">https://drive.google.com/</a>.
#
# Ten en cuenta que solo se puede leer, escribir o mover archivos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd

# %%
import pandef dataSize (df):das as pd
import io

df = pd.read_csv("netflix_titles.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-32dc890572c4> in <module>()
# ----> 1 import panas as pd
#       2 import io
#       3
#       4 #df = pd.read_csv("content\drive\mydrive\semanaTec-Sep21\arte-analitica\data\netflix_titles.csv")
#
# ModuleNotFoundError: No module named 'panas'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
with open('/content/drive/My Drive/semanaTec-Sep21/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/semanaTec/foo.txt
# Out:
# cat: '/content/drive/My Drive/semanaTec/foo.txt': No such file or directory

# %% [markdown]
# ## PyDrive
#
# En los ejemplos que aparecen a continuación, se muestran la autenticación y la carga y descarga de archivos mediante PyDrive. Puedes encontrar más ejemplos en la <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">documentación de PyDrive</a>.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Autentica y crea el cliente de PyDrive.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Lista de ids de cada carpeta que tenemos en el google drive

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:       
    print ('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: semanaTec-Sep21, id: 1IV2y-Yu3mTtZjboOK8ngwEEeD7eqOKwR
# title: Situacion Problema - Ecuaciones Diferenciales, id: 1JUPfFXY-06DoiQR5LTa9z0MRAI1V0Kyo
# title: Evidencia - Arte, id: 1dyMMrrOb3jH9UFfFRpCR1bPKa6bp6bVK
# title: Copia de Evidencia 1 Diagnóstico_ Equipo 4, id: 1GJUvkhT0o9o9PMOwpotKytz6albCuXzGHCuRZ55_d3k
# title: Actividad 4,5 y 8, id: 1f3ddkVoD9zlhdzcED3b2_9UFj9sxTs3ceUc-1kkG6Xs
# title: temp, id: 1hCpH10Y-GGrH8rB-RVKhih3-4546buG-qqcawo7t2zQ
# title: Documento sin título, id: 1XqjaMU-sClnz2fMMAd3uon6nenrmn-RtN3uBvq4QtKc
# title: MA1031_Situación Problema2_FJ21_T3-ocg, id: 1oLTNMs8MsmVLA5pkG7uxPUEUOOkztzqafKIF6_pUQmU
# title: Evidencia 2, id: 15ZQL3dMQTgdRfRyssgkc3nMnkZsTNdTs
# title: Caída Libre de un Imán, id: 1mos7FGbLYR0ibAhJaB9LcvwSyr7ez7IdVKr4Ee1gN2A
# title: Etapa 4 , id: 1Ta2KV-d1Bw7U3N7MJGW58X_ZQv0GlbhB
# title: SP1_G27_EQUIPO_8, id: 15proC3Ybbk_1l1IHl4iAkCiNYUy5sGC7V45Tfs7xYLA
# title: Situacon Problema 1, id: 17pkUZOmeaAFxilCuJv0KnklpeUAlbnqi
# title: MA1031_SP1_FJ21_T3A, id: 12PGZPudH0iOO6x8_zGNb7DXHFxx8rAImM9BDb4cISn0
# title: Datos - Excel, id: 1LjGgN56t4dS9msnYG4xR1gYU07s6bR_n
# title: Calculos - Entrega 1, id: 1Dsk_nEX6uZriFyb7QfPBkVlO8les9TySvYLdr_oBdw4
# title: Electromagnitismo, id: 1eadL0m-lSC5c163TQqZTAbfJC926DQPV
# title: Barcamp - Techo - Equipo 3, id: 1N85jbF0yTUVFij8ndMi5x1iTzSHXDbQTiIprlHQpsK4
# title: Investigacion - Techo - Servicio Social, id: 195T4kx3MEe-7wQUunJjSHsCkEihCSNk-Z1yrrtebgBg
# title: Reto: Entrega Final, id: 17WgJboEkIeTnxbT_SdYWb6i1_tteKhL80KLSHfle2rQ
# title: Entrevista, id: 1X9xt9CUPEYP05yyYGMBb8IKei-CxXHPc
# title: Video - Modelacion Computacional de Sistemas Electricos, id: 1zpYR4-VPzW3Tq_ccnEXbU1Pqvmua299S
# title: Evidencia 2, id: 1Rz8eRjLF008J2JSV7ThEwJWQpyFf3qRD
# title: Calculos - Situacion Problema, id: 16qBYfqQqn_9zBGKvldlIS7ouYCtzS0ls
# title: Modelacion Computacional de Sistemas Electricos, id: 1Bckbi4Ad4npYQYyHv9ku2Ttq9Y0tP84l
# title: Colab Notebooks, id: 1n-wdD_bErKNXw3iXLEFIouPrK7PgLNkg
# title: macromoléculas_A00832494, id: 1Xf1DkzUnxy_4Bofp6JVROu-xEJhYQxbPPkRz20vxMRc
# title: Fact, id: 1O0PraOcz4mofz6_U5uxZ061wcRSx-HU-kRLSccQVArA
# title: Ayudanos a Crear el Vaso Perfecto! (Respuestas), id: 1P3i77JCcV9gGxd7VNiRvcq3gzrZ2TzT1-ewdPsQy3ew
# title: Evaluacion Oral - Alejandro Melendez Torres - A00832494, id: 1obl4qxYqFskEYBM02Zpb9vHcAWcVXPFKDUlBaYi4yJs
# title: 2do Experimento, id: 1LAWPTNNpjCb88w4yTEfdro9KCH5_TDuK-hBE3_hW9y8
# title: 2do Experimento, id: 1KESoJrLLZLHvNLQDCjScI4nH5KqAO06N
# title: Reto Etapa 2, id: 141jZ-kgwKlYGL_TdIQi_NYO5qrdKMq2ZmTCDz7pKTo4
# title: Ayudanos a Crear el Vaso Perfecto!, id: 1qjPRaHb9fxVMtJ86pLbmaw4p9azcemKvYtnJqZCztxc
# title: 1er Experimento, id: 1LutEFuJhkxAQkUlWkul2pOa2NtVrionO
# title: Equipo 1 - Bloque 3:00, id: 1O1sXL2MzfAgB9Yu2yHMF1uNcgn6Z_syO04ugpm5wOgY
# title: Pasaporte AMT v2017.pdf, id: 1V4hGw1hkjyQgKs_aDtt0FP0kx6OAXmpW
# title: Credencial Elector AMT vLow.pdf, id: 1xIXnfYFgzJbc51lUrAsmH-dKUjJLI8pB
# title: Solicitud ITESM AMT 30-Jan-2020 11-05-13.pdf, id: 17lR6a-iyzGsbuPqsrOZHeyZC_GjLFun0
# title: Codigo de Etica.jpeg, id: 1C6uvrZs5WuGkrqG7LCSPVtbIUs5V73jj
# title: Responsable de Pago.jpeg, id: 12cnLEq4JQ1CCrk_dnQQROLSWORgrGhgI
# title: Melendez Torres Alejandro (1).pdf, id: 1X_LuAs2fcPRyidwSJzeVCL-EcUNHjdfL
# title: Melendez Torres Alejandro (1).pdf, id: 1QC-Co0Op8DQfFviQbb_yh-DT1_yzaNfj
# title: Melendez Torres-Sec (1).pdf, id: 1C75gsMGjzCN1CmE7lbd1vvdA-E8qfMwT
# title: Solicitud ITESM AMT 30-Jan-2020 11-05-13.pdf, id: 1budHZsDSGqarh6eOb13O9irF3kmWehR7
# title: CURP_META010809HNLLRLA1.pdf, id: 1VqMLlC95rKbqN1DfSOUTiNETE6IyA_7-
# title: Acta Nacimiento AMT v2019_09.pdf, id: 1MTkUIn_GBiCikF-s_0aihl4uYqjNUxUg
# title: Presentación sin título, id: 1rRCuQefwdbpMI2WMSFUsE99fkYIGJ35Tjryi5GjB_Kc
# title: EBSCO, id: 1ltY_Mx8ydwAeV78t7U3eNz31ehF6I-1V
# title: 2020_11_26 - Hoddie A00832494 Hoodie AMT - 1606442071.pdf, id: 1VyvdX3zIxBpVWNpNhc2XV96f3MoILJTQ
# title: Riesgos y Criticas sobre el Internet, id: 1F04qn7nd8iQZ3UrZRVCMNqWBj1sCU340cQyKuTv_CzM
# title: Equipo 3 - Spotify, id: 1yKBnCaHbofOqTFUxpPWYtPJA-Vw_FQIu3RWZ2lo-wWM
# title: equipo_3.mp4, id: 11TZfOQBoBzVP2tA14fz-PGsJ5OQpzapP
# title: Bitacora Final - Alejandro Melendez Torres, id: 1cRJmj6TXIA9xItXoAeVD_ZmNjFRIbfn9kDj3gef1DIg
# title: Portada.JPG, id: 18LIxktJ1X1QT4udAti44sjgPYcenmYfG
# title: Calculos - Examen Argumentativo - Alejandro Melendez Torres, id: 1EnI18elWzkff4OuuKbewYAntef8gEuxmULufDvnaoW4
# title: Equipo 3 - Energias Renovables, id: 18-9URBjVIhNxS3iFAhIOOoZR3Lv2qXAJGttkNDubMco
# title: Mapamundi - Acceso a Internet, id: 1RCQDPTL3vCU-mnx0DAWkfyQQNwNYXNk0YPR3fbBQmsU
# title: uno, id: 1CMC70jzOe6HQB0mhBe_e8yHPr1DD6PwMlp5C5ddEc2E
# title: Documento sin título, id: 1c-0wzLjbm0djpIg0Iny8QevqYobCZHG1hn15VxjActI
# title: Reto - Equipo 4, id: 14Z4zanse4qMkpLRFUa7X2p8nCL4aRvjbcC6z5mHtPzs
# title: Vacuna del Coronavirus, id: 14vJ3zWRbT-mH2dOI4O5JVYTbZw_u_QMhVBt26HSd4Y0
# title: Equipo 1 - Reglamento, id: 1T6-U7WGmv71o7P4IeqbSDwYGxq5QeThke89DcyIfUvw
# title: Equipo 6, id: 19Vp8yrytNNJiXz1NkED6XcwM7VriPX1hYVeM32bh6aQ

# %%
fid= '1r3STNnFiq8uRhifgq96dbO2keF58zFqU'

# %% [markdown]
# Crea y sube un archivo de texto.

# %%
uploaded = drive.CreateFile({'title': 'Sample upload.txt','parents':[{"id":fid}]})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1fzU8VPHCQqGPW9H6tmK0QcvZqqhGoOSQ

# %% [markdown]
# Carga un archivo por su ID y luego imprime su contenido.

# %%
uploaded.get('id')
# Out:
# '1irKkQkYNkGqKVMitMGtJtK3nJYbZ8OAX'

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content
# modificar"

# %% [markdown]
# # Hojas de cálculo de Google
#
# Los ejemplos de abajo usan la biblioteca de código abierto <a href="https://github.com/burnash/gspread"><code>gspread</code></a> para interactuar con Hojas de cálculo de Google.
#
# Primero, instala el paquete usando <code>pip</code>.

# %%
# !pip install --upgrade --quiet gspread

# %% [markdown]
# Importa la biblioteca, autentica y crea la interfaz para Hojas de cálculo.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# A continuación, verás un pequeño conjunto de ejemplos de <code>gspread</code>. Puedes encontrar más ejemplos en la <a href="https://github.com/burnash/gspread#more-examples">página de GitHub de <code>gspread</code></a>.

# %% [markdown]
# ## Crear una hoja nueva con datos de Python

# %%
sh = gc.create('My cool spreadsheet')

# %% [markdown]
# Después de ejecutar la celda anterior, se mostrará una nueva hoja de cálculo con el nombre "My cool spreadsheet" en <a href="https://sheets.google.com/">https://sheets.google.com</a>.
#
# Abre la hoja nueva y agrega datos aleatorios.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1tE6ynMLATZl1HJtFGp9KmjmjC292JTNEgyu8BK4ZBtU',
#  'updatedCells': 6,
#  'updatedColumns': 3,
#  'updatedRange': 'Sheet1!A1:C2',
#  'updatedRows': 2}

# %% [markdown]
# ## Descargar datos de una hoja de cálculo en Python como un DataFrame de Pandas
#
# Vuelve a leer los datos aleatorios que insertamos anteriormente y convierte el resultado en un <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html">DataFrame de Pandas</a>.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print('******************Lista de datos*********************')
print(rows)

import pandas as pd
dataset=pd.DataFrame.from_records(rows)
print('******************Data Frame*********************')
print(dataset)
# Out:
# ******************Lista de datos*********************
# [['9', '4', '10'], ['4', '2', '7']]
# ******************Data Frame*********************
#    0  1   2
# 0  9  4  10
# 1  4  2   7
